# %% [markdown]
# ## Let's check the environment first thing

# %%
import sys
sys.executable
# Out:
# 'C:\\Users\\Mansoor\\anaconda3\\envs\\rainfall_prediction\\python.exe'

# %%
run_sample = False
sample_pct = 0.10

# %% [markdown]
# ### Read and Display the data

# %%
import pandas as pd

pd.set_option('display.max_columns', None)

weather_data = pd.read_csv('weatherAUS.csv')
weather_data.head()
# Out:
#         Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  12/1/2008   Albury     13.4     22.9       0.6          NaN       NaN
# 1  12/2/2008   Albury      7.4     25.1       0.0          NaN       NaN
# 2  12/3/2008   Albury     12.9     25.7       0.0          NaN       NaN
# 3  12/4/2008   Albury      9.2     28.0       0.0          NaN       NaN
# 4  12/5/2008   Albury     17.5     32.3       1.0          NaN       NaN
#
#   WindGustDir  WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  \
# 0           W           44.0          W        WNW          20.0
# 1         WNW           44.0        NNW        WSW           4.0
# 2         WSW           46.0          W        WSW          19.0
# 3          NE           24.0         SE          E          11.0
# 4           W           41.0        ENE         NW           7.0
#
#    WindSpeed3pm  Humidity9am  Humidity3pm  Pressure9am  Pressure3pm  Cloud9am  \
# 0          24.0         71.0         22.0       1007.7       1007.1       8.0
# 1          22.0         44.0         25.0       1010.6       1007.8       NaN
# 2          26.0         38.0         30.0       1007.6       1008.7       NaN
# 3           9.0         45.0         16.0       1017.6       1012.8       NaN
# 4          20.0         82.0         33.0       1010.8       1006.0       7.0
#
#    Cloud3pm  Temp9am  Temp3pm RainToday RainTomorrow
# 0       NaN     16.9     21.8        No           No
# 1       NaN     17.2     24.3        No           No
# 2       2.0     21.0     23.2        No           No
# 3       NaN     18.1     26.5        No           No
# 4       8.0     17.8     29.7        No           No

# %%
weather_data.describe().T
# Out:
#                   count         mean        std    min     25%     50%  \
# MinTemp        141556.0    12.186400   6.403283   -8.5     7.6    12.0
# MaxTemp        141871.0    23.226784   7.117618   -4.8    17.9    22.6
# Rainfall       140787.0     2.349974   8.465173    0.0     0.0     0.0
# Evaporation     81350.0     5.469824   4.188537    0.0     2.6     4.8
# Sunshine        74377.0     7.624853   3.781525    0.0     4.9     8.5
# WindGustSpeed  132923.0    39.984292  13.588801    6.0    31.0    39.0
# WindSpeed9am   140845.0    14.001988   8.893337    0.0     7.0    13.0
# WindSpeed3pm   139563.0    18.637576   8.803345    0.0    13.0    19.0
# Humidity9am    140419.0    68.843810  19.051293    0.0    57.0    70.0
# Humidity3pm    138583.0    51.482606  20.797772    0.0    37.0    52.0
# Pressure9am    128179.0  1017.653758   7.105476  980.5  1012.9  1017.6
# Pressure3pm    128212.0  1015.258204   7.036677  977.1  1010.4  1015.2
# Cloud9am        88536.0     4.437189   2.887016    0.0     1.0     5.0
# Cloud3pm        85099.0     4.503167   2.720633    0.0     2.0     5.0
# Temp9am        141289.0    16.987509   6.492838   -7.2    12.3    16.7
# Temp3pm        139467.0    21.687235   6.937594   -5.4    16.6    21.1
#
#                   75%     max
# MinTemp          16.8    33.9
# MaxTemp          28.2    48.1
# Rainfall          0.8   371.0
# Evaporation       7.4   145.0
# Sunshine         10.6    14.5
# WindGustSpeed    48.0   135.0
# WindSpeed9am     19.0   130.0
# WindSpeed3pm     24.0    87.0
# Humidity9am      83.0   100.0
# Humidity3pm      66.0   100.0
# Pressure9am    1022.4  1041.0
# Pressure3pm    1020.0  1039.6
# Cloud9am          7.0     9.0
# Cloud3pm          7.0     9.0
# Temp9am          21.6    40.2
# Temp3pm          26.4    46.7

# %%
# Date column is of no relevance here, hence dropping. It has unique value for each record

weather_data.drop('Date', axis=1, inplace=True)

# %% [markdown]
# ## Step 1 – Exploratory Data Analysis

# %%
weather_data.shape
# Out:
# (142193, 22)

# %%
weather_data['RainTomorrow'].value_counts()
# Out:
# No     110316
# Yes     31877
# Name: RainTomorrow, dtype: int64

# %%
weather_data['RainTomorrow'].value_counts(normalize=True)
# Out:
# No     0.775819
# Yes    0.224181
# Name: RainTomorrow, dtype: float64

# %%
weather_sample = weather_data.sample(frac=sample_pct)
weather_sample['RainTomorrow'].value_counts(normalize=True)
# Out:
# No     0.772277
# Yes    0.227723
# Name: RainTomorrow, dtype: float64

# %%
weather_data.shape, weather_sample.shape
# Out:
# ((142193, 22), (14219, 22))

# %%
weather_data.shape
# Out:
# (142193, 22)

# %%
# For testing purpose, run with 10% of data
if run_sample:
    weather_data = weather_sample.copy()

# %%
weather_data.shape
# Out:
# (142193, 22)

# %%
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(8, 5))

weather_data['RainTomorrow'].value_counts(normalize=True).plot(kind='bar', color = ['darkgrey', 'green'], alpha=0.8, rot=0)
plt.title('RainTomorrow - No Rain vs Rain')
plt.show()

# %%
from collections import Counter

Counter(weather_data['RainTomorrow'])
# Out:
# Counter({'No': 110316, 'Yes': 31877})

# %% [markdown]
# ### Let's check for missing values

# %%
miss_pct = (weather_data.isnull().sum() * 100 / len(weather_data)).sort_values(ascending=False)
miss_sum = (weather_data.isnull().sum()).sort_values(ascending=False)

missing = pd.concat([miss_sum, miss_pct], axis=1, keys=['Total', 'Percent'])
missing
# Out:
#                Total    Percent
# Sunshine       67816  47.692924
# Evaporation    60843  42.789026
# Cloud3pm       57094  40.152469
# Cloud9am       53657  37.735332
# Pressure9am    14014   9.855619
# Pressure3pm    13981   9.832411
# WindDir9am     10013   7.041838
# WindGustDir     9330   6.561504
# WindGustSpeed   9270   6.519308
# WindDir3pm      3778   2.656952
# Humidity3pm     3610   2.538803
# Temp3pm         2726   1.917113
# WindSpeed3pm    2630   1.849599
# Humidity9am     1774   1.247600
# RainToday       1406   0.988797
# Rainfall        1406   0.988797
# WindSpeed9am    1348   0.948007
# Temp9am          904   0.635756
# MinTemp          637   0.447983
# MaxTemp          322   0.226453
# Location           0   0.000000
# RainTomorrow       0   0.000000

# %% [markdown]
# ## Step 2 – Feature Engineering

# %% [markdown]
# > We need to predict 'RainTomorrow' based on other dependent features. Let's convert RainToday and RainTomorrow from Yes/No to 1/0

# %%
weather_data['RainToday'].replace({'Yes': 1, 'No': 0}, inplace=True)
weather_data['RainTomorrow'].replace({'Yes': 1, 'No': 0}, inplace=True)

weather_data.head(20)
# Out:
#    Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0    Albury     13.4     22.9       0.6          NaN       NaN           W
# 1    Albury      7.4     25.1       0.0          NaN       NaN         WNW
# 2    Albury     12.9     25.7       0.0          NaN       NaN         WSW
# 3    Albury      9.2     28.0       0.0          NaN       NaN          NE
# 4    Albury     17.5     32.3       1.0          NaN       NaN           W
# 5    Albury     14.6     29.7       0.2          NaN       NaN         WNW
# 6    Albury     14.3     25.0       0.0          NaN       NaN           W
# 7    Albury      7.7     26.7       0.0          NaN       NaN           W
# 8    Albury      9.7     31.9       0.0          NaN       NaN         NNW
# 9    Albury     13.1     30.1       1.4          NaN       NaN           W
# 10   Albury     13.4     30.4       0.0          NaN       NaN           N
# 11   Albury     15.9     21.7       2.2          NaN       NaN         NNE
# 12   Albury     15.9     18.6      15.6          NaN       NaN           W
# 13   Albury     12.6     21.0       3.6          NaN       NaN          SW
# 14   Albury      9.8     27.7       NaN          NaN       NaN         WNW
# 15   Albury     14.1     20.9       0.0          NaN       NaN         ENE
# 16   Albury     13.5     22.9      16.8          NaN       NaN           W
# 17   Albury     11.2     22.5      10.6          NaN       NaN         SSE
# 18   Albury      9.8     25.6       0.0          NaN       NaN         SSE
# 19   Albury     11.5     29.3       0.0          NaN       NaN           S
#
#     WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  WindSpeed3pm  \
# 0            44.0          W        WNW          20.0          24.0
# 1            44.0        NNW        WSW           4.0          22.0
# 2            46.0          W        WSW          19.0          26.0
# 3            24.0         SE          E          11.0           9.0
# 4            41.0        ENE         NW           7.0          20.0
# 5            56.0          W          W          19.0          24.0
# 6            50.0         SW          W          20.0          24.0
# 7            35.0        SSE          W           6.0          17.0
# 8            80.0         SE         NW           7.0          28.0
# 9            28.0          S        SSE          15.0          11.0
# 10           30.0        SSE        ESE          17.0           6.0
# 11           31.0         NE        ENE          15.0          13.0
# 12           61.0        NNW        NNW          28.0          28.0
# 13           44.0          W        SSW          24.0          20.0
# 14           50.0        NaN        WNW           NaN          22.0
# 15           22.0        SSW          E          11.0           9.0
# 16           63.0          N        WNW           6.0          20.0
# 17           43.0        WSW         SW          24.0          17.0
# 18           26.0         SE        NNW          17.0           6.0
# 19           24.0         SE         SE           9.0           9.0
#
#     Humidity9am  Humidity3pm  Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  \
# 0          71.0         22.0       1007.7       1007.1       8.0       NaN
# 1          44.0         25.0       1010.6       1007.8       NaN       NaN
# 2          38.0         30.0       1007.6       1008.7       NaN       2.0
# 3          45.0         16.0       1017.6       1012.8       NaN       NaN
# 4          82.0         33.0       1010.8       1006.0       7.0       8.0
# 5          55.0         23.0       1009.2       1005.4       NaN       NaN
# 6          49.0         19.0       1009.6       1008.2       1.0       NaN
# 7          48.0         19.0       1013.4       1010.1       NaN       NaN
# 8          42.0          9.0       1008.9       1003.6       NaN       NaN
# 9          58.0         27.0       1007.0       1005.7       NaN       NaN
# 10         48.0         22.0       1011.8       1008.7       NaN       NaN
# 11         89.0         91.0       1010.5       1004.2       8.0       8.0
# 12         76.0         93.0        994.3        993.0       8.0       8.0
# 13         65.0         43.0       1001.2       1001.8       NaN       7.0
# 14         50.0         28.0       1013.4       1010.3       0.0       NaN
# 15         69.0         82.0       1012.2       1010.4       8.0       1.0
# 16         80.0         65.0       1005.8       1002.2       8.0       1.0
# 17         47.0         32.0       1009.4       1009.7       NaN       2.0
# 18         45.0         26.0       1019.2       1017.1       NaN       NaN
# 19         56.0         28.0       1019.3       1014.8       NaN       NaN
#
#     Temp9am  Temp3pm  RainToday  RainTomorrow
# 0      16.9     21.8        0.0             0
# 1      17.2     24.3        0.0             0
# 2      21.0     23.2        0.0             0
# 3      18.1     26.5        0.0             0
# 4      17.8     29.7        0.0             0
# 5      20.6     28.9        0.0             0
# 6      18.1     24.6        0.0             0
# 7      16.3     25.5        0.0             0
# 8      18.3     30.2        0.0             1
# 9      20.1     28.2        1.0             0
# 10     20.4     28.8        0.0             1
# 11     15.9     17.0        1.0             1
# 12     17.4     15.8        1.0             1
# 13     15.8     19.8        1.0             0
# 14     17.3     26.2        NaN             0
# 15     17.2     18.1        0.0             1
# 16     18.0     21.5        1.0             1
# 17     15.5     21.0        1.0             0
# 18     15.8     23.2        0.0             0
# 19     19.1     27.3        0.0             0

# %%
weather_data.shape
# Out:
# (142193, 22)

# %% [markdown]
# ### Train Test Split

# %%
from sklearn.model_selection import train_test_split

# %%
y = weather_data['RainTomorrow']
X = weather_data.drop('RainTomorrow', axis=1)
X.shape
# Out:
# (142193, 21)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=10)
X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((99535, 21), (99535,), (42658, 21), (42658,))

# %%
142193* .1 * .7
# Out:
# 9953.51

# %%
miss_pct = (X_train.isnull().sum() * 100 / len(X_train)).sort_values(ascending=False)
miss_sum = (X_train.isnull().sum()).sort_values(ascending=False)

missing = pd.concat([miss_sum, miss_pct], axis=1, keys=['Total', 'Percent'])
missing
# Out:
#                Total    Percent
# Sunshine       47616  47.838449
# Evaporation    42701  42.900487
# Cloud3pm       40037  40.224042
# Cloud9am       37562  37.737479
# Pressure9am     9822   9.867886
# Pressure3pm     9811   9.856834
# WindDir9am      6989   7.021651
# WindGustDir     6585   6.615763
# WindGustSpeed   6547   6.577586
# WindDir3pm      2654   2.666399
# Humidity3pm     2503   2.514693
# Temp3pm         1900   1.908876
# WindSpeed3pm    1861   1.869694
# Humidity9am     1228   1.233737
# RainToday        983   0.987592
# Rainfall         983   0.987592
# WindSpeed9am     954   0.958457
# Temp9am          630   0.632943
# MinTemp          444   0.446074
# MaxTemp          228   0.229065
# Location           0   0.000000

# %% [markdown]
# ### Label Encoding the Categorical features

# %%
from sklearn.preprocessing import LabelEncoder
import numpy as np

class LabelEncoderExt(object):
    def __init__(self):
        """
        It differs from LabelEncoder by handling new classes and providing a value for it [Unknown]
        Unknown will be added in fit and transform will take care of new item. It gives unknown class id
        """
        self.label_encoder = LabelEncoder()
        # self.classes_ = self.label_encoder.classes_

    def fit(self, data_list):
        """
        This will fit the encoder for all the unique values and introduce unknown value
        :param data_list: A list of string
        :return: self
        """
        self.label_encoder = self.label_encoder.fit(list(data_list) + ['Unknown'])
        self.classes_ = self.label_encoder.classes_

        return self

    def transform(self, data_list):
        """
        This will transform the data_list to id list where the new values get assigned to Unknown class
        :param data_list:
        :return:
        """
        new_data_list = list(data_list)
        for unique_item in np.unique(data_list):
            if unique_item not in self.label_encoder.classes_:
                new_data_list = ['Unknown' if x==unique_item else x for x in new_data_list]

        return self.label_encoder.transform(new_data_list)

# %%
categorical_columns = X_train.select_dtypes(include=['object']).columns
categorical_columns, len(categorical_columns)
# Out:
# (Index(['Location', 'WindGustDir', 'WindDir9am', 'WindDir3pm'], dtype='object'),
#  4)

# %%
numerical_columns = X_train.select_dtypes(exclude=['object']).columns
numerical_columns, len(numerical_columns)
# Out:
# (Index(['MinTemp', 'MaxTemp', 'Rainfall', 'Evaporation', 'Sunshine',
#         'WindGustSpeed', 'WindSpeed9am', 'WindSpeed3pm', 'Humidity9am',
#         'Humidity3pm', 'Pressure9am', 'Pressure3pm', 'Cloud9am', 'Cloud3pm',
#         'Temp9am', 'Temp3pm', 'RainToday'],
#        dtype='object'),
#  17)

# %%
X_train[categorical_columns]
# Out:
#             Location WindGustDir WindDir9am WindDir3pm
# 106233        Albany         NaN        WSW          W
# 96877       Adelaide         ENE          N        WNW
# 109078   Witchcliffe           N         NE          N
# 37945     WaggaWagga         ESE        ENE        ENE
# 49491    Tuggeranong         WNW        NaN        WNW
# ...              ...         ...        ...        ...
# 9372    CoffsHarbour         WSW        WSW        ESE
# 105595       Woomera         WNW        NNW         NW
# 93553     Townsville         ENE          S        ENE
# 94735       Adelaide         ESE        SSW          S
# 83209       Brisbane          NE          E         NE
#
# [99535 rows x 4 columns]

# %%
X_train[categorical_columns].isnull().sum()
# Out:
# Location          0
# WindGustDir    6585
# WindDir9am     6989
# WindDir3pm     2654
# dtype: int64

# %%
from pickle import dump
lencoders = {}

for col in categorical_columns:
    lencoders[col] = LabelEncoderExt()
    lencoders[col].fit(X_train[col])
    X_train[col] = lencoders[col].transform(X_train[col].astype('str'))
    X_test[col] = lencoders[col].transform(X_test[col].astype('str'))
    
dump(lencoders, open('labelencoder.pkl', 'wb'))

# %% [markdown]
# > Note: All the null values from categorical features will be given a new label which typically will be one more than the last assigned label. Ex. if Female = 0 and Male = 1, then missing will be assigned 2

# %%
X_train[categorical_columns].isnull().sum()
# Out:
# Location       0
# WindGustDir    0
# WindDir9am     0
# WindDir3pm     0
# dtype: int64

# %%
X_train[categorical_columns]
# Out:
#         Location  WindGustDir  WindDir9am  WindDir3pm
# 106233         1           17          16          14
# 96877          0            1           3          15
# 109078        47            3           4           3
# 37945         43            2           1           1
# 49491         40           15          17          15
# ...          ...          ...         ...         ...
# 9372          11           16          16           2
# 105595        49           15           6           7
# 93553         39            1           8           1
# 94735          0            2          11           8
# 83209          7            4           0           4
#
# [99535 rows x 4 columns]

# %% [markdown]
# ### WindGustDir had 6585 missing values on full data, did they get encoded with 17? Lets check!

# %%
X_train['WindGustDir'].value_counts().sort_index()[-1:]
# Out:
# 17    6585
# Name: WindGustDir, dtype: int64

# %%
for col in categorical_columns:
    #print(col)
    print(X_train[col].value_counts().sort_index()[-1:])
    print('--' * 60)
# Out:
# 49    2084
# Name: Location, dtype: int64
# ------------------------------------------------------------------------------------------------------------------------
# 17    6585
# Name: WindGustDir, dtype: int64
# ------------------------------------------------------------------------------------------------------------------------
# 17    6989
# Name: WindDir9am, dtype: int64
# ------------------------------------------------------------------------------------------------------------------------
# 17    2654
# Name: WindDir3pm, dtype: int64
# ------------------------------------------------------------------------------------------------------------------------

# %%
X_train['WindDir3pm'].value_counts().sort_index()
# Out:
# 0     5817
# 1     5379
# 2     5821
# 3     6095
# 4     5747
# 5     4527
# 6     5344
# 7     5961
# 8     6575
# 9     7488
# 10    6451
# 11    5628
# 12    6480
# 14    6921
# 15    6085
# 16    6562
# 17    2654
# Name: WindDir3pm, dtype: int64

# %% [markdown]
# > WindDir3pm, WindDir9am, WindGustDir - For these features, the value of 16 would imply a NaN, so this has to be replaced during Impuation of missing values.

# %% [markdown]
# ### Lets use KNN Imputer to impute missing values, but before that we need to normalize the data

# %%
X_train.isnull().sum()
# Out:
# Location             0
# MinTemp            444
# MaxTemp            228
# Rainfall           983
# Evaporation      42701
# Sunshine         47616
# WindGustDir          0
# WindGustSpeed     6547
# WindDir9am           0
# WindDir3pm           0
# WindSpeed9am       954
# WindSpeed3pm      1861
# Humidity9am       1228
# Humidity3pm       2503
# Pressure9am       9822
# Pressure3pm       9811
# Cloud9am         37562
# Cloud3pm         40037
# Temp9am            630
# Temp3pm           1900
# RainToday          983
# dtype: int64

# %%
X_train.head()
# Out:
#         Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 106233         1      8.4     13.8       9.2          4.0       6.9
# 96877          0     14.0     27.8       0.0          NaN       NaN
# 109078        47      6.5     28.5       0.2          NaN       NaN
# 37945         43     20.5     34.9       0.0          7.6       9.8
# 49491         40      6.0     29.1       0.0          NaN       NaN
#
#         WindGustDir  WindGustSpeed  WindDir9am  WindDir3pm  WindSpeed9am  \
# 106233           17            NaN          16          14          44.0
# 96877             1           22.0           3          15           6.0
# 109078            3           35.0           4           3          13.0
# 37945             2           57.0           1           1          22.0
# 49491            15           39.0          17          15           0.0
#
#         WindSpeed3pm  Humidity9am  Humidity3pm  Pressure9am  Pressure3pm  \
# 106233          28.0         52.0         55.0       1009.0       1010.6
# 96877            7.0         49.0         30.0       1021.4       1018.9
# 109078          17.0         53.0         27.0       1023.3       1020.1
# 37945           13.0         53.0         33.0       1016.7       1014.2
# 49491           17.0         47.0         25.0       1012.3       1008.9
#
#         Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday
# 106233       6.0       6.0     11.4     12.2        1.0
# 96877        NaN       NaN     20.7     27.2        0.0
# 109078       NaN       NaN     21.1     27.9        0.0
# 37945        2.0       4.0     25.7     33.7        0.0
# 49491        NaN       NaN     18.4     28.0        0.0

# %%
from sklearn.preprocessing import MinMaxScaler
import numpy as np

from pickle import dump, load

scaler = {}

for col in numerical_columns:
    scaler[col] = MinMaxScaler()
    X_train[col] = scaler[col].fit_transform(np.array(X_train[col]).reshape(-1, 1))
    X_test[col]  = scaler[col].transform(np.array(X_test[col]).reshape(-1, 1))

dump(scaler, open('scaler.pkl', 'wb'))

# %%
X_train.head()
# Out:
#         Location   MinTemp   MaxTemp  Rainfall  Evaporation  Sunshine  \
# 106233         1  0.398585  0.357006  0.024798     0.027586  0.482517
# 96877          0  0.530660  0.625720  0.000000          NaN       NaN
# 109078        47  0.353774  0.639155  0.000539          NaN       NaN
# 37945         43  0.683962  0.761996  0.000000     0.052414  0.685315
# 49491         40  0.341981  0.650672  0.000000          NaN       NaN
#
#         WindGustDir  WindGustSpeed  WindDir9am  WindDir3pm  WindSpeed9am  \
# 106233           17            NaN          16          14      0.338462
# 96877             1       0.124031           3          15      0.046154
# 109078            3       0.224806           4           3      0.100000
# 37945             2       0.395349           1           1      0.169231
# 49491            15       0.255814          17          15      0.000000
#
#         WindSpeed3pm  Humidity9am  Humidity3pm  Pressure9am  Pressure3pm  \
# 106233      0.321839     0.515152         0.55     0.471074     0.542071
# 96877       0.080460     0.484848         0.30     0.676033     0.676375
# 109078      0.195402     0.525253         0.27     0.707438     0.695793
# 37945       0.149425     0.525253         0.33     0.598347     0.600324
# 49491       0.195402     0.464646         0.25     0.525620     0.514563
#
#         Cloud9am  Cloud3pm   Temp9am   Temp3pm  RainToday
# 106233  0.666667      0.75  0.401728  0.337812        1.0
# 96877        NaN       NaN  0.602592  0.625720        0.0
# 109078       NaN       NaN  0.611231  0.639155        0.0
# 37945   0.222222      0.50  0.710583  0.750480        0.0
# 49491        NaN       NaN  0.552916  0.641075        0.0

# %%
from datetime import datetime
print(datetime.now())
# Out:
# 2021-10-06 22:04:27.606652

# %%
from sklearn.impute import KNNImputer
import numpy as np

imputer = KNNImputer(n_neighbors=5, weights='uniform', missing_values=np.nan)
new_array = imputer.fit_transform(X_train)
X_train = pd.DataFrame(data=new_array, columns=X_train.columns, index=X_train.index)
X_train.head()
# Out:
#         Location   MinTemp   MaxTemp  Rainfall  Evaporation  Sunshine  \
# 106233       1.0  0.398585  0.357006  0.024798     0.027586  0.482517
# 96877        0.0  0.530660  0.625720  0.000000     0.053517  0.837762
# 109078      47.0  0.353774  0.639155  0.000539     0.041103  0.675524
# 37945       43.0  0.683962  0.761996  0.000000     0.052414  0.685315
# 49491       40.0  0.341981  0.650672  0.000000     0.043310  0.742657
#
#         WindGustDir  WindGustSpeed  WindDir9am  WindDir3pm  WindSpeed9am  \
# 106233         17.0       0.341085        16.0        14.0      0.338462
# 96877           1.0       0.124031         3.0        15.0      0.046154
# 109078          3.0       0.224806         4.0         3.0      0.100000
# 37945           2.0       0.395349         1.0         1.0      0.169231
# 49491          15.0       0.255814        17.0        15.0      0.000000
#
#         WindSpeed3pm  Humidity9am  Humidity3pm  Pressure9am  Pressure3pm  \
# 106233      0.321839     0.515152         0.55     0.471074     0.542071
# 96877       0.080460     0.484848         0.30     0.676033     0.676375
# 109078      0.195402     0.525253         0.27     0.707438     0.695793
# 37945       0.149425     0.525253         0.33     0.598347     0.600324
# 49491       0.195402     0.464646         0.25     0.525620     0.514563
#
#         Cloud9am  Cloud3pm   Temp9am   Temp3pm  RainToday
# 106233  0.666667      0.75  0.401728  0.337812        1.0
# 96877   0.400000      0.55  0.602592  0.625720        0.0
# 109078  0.622222      0.85  0.611231  0.639155        0.0
# 37945   0.222222      0.50  0.710583  0.750480        0.0
# 49491   0.377778      0.10  0.552916  0.641075        0.0

# %%
X_train.shape
# Out:
# (99535, 21)

# %%
X_test.head()
# Out:
#         Location   MinTemp   MaxTemp  Rainfall  Evaporation  Sunshine  \
# 86783          8  0.695755  0.577735  0.001078     0.017931  0.055944
# 76156         45  0.622642  0.788868  0.000000     0.068966  0.615385
# 28773         34  0.334906  0.414587  0.000000          NaN       NaN
# 128019        15  0.455189  0.404990  0.021563     0.027586  0.489510
# 85872          8  0.724057  0.700576  0.000000     0.042759  0.741259
#
#         WindGustDir  WindGustSpeed  WindDir9am  WindDir3pm  WindSpeed9am  \
# 86783            10       0.341085          10          10      0.184615
# 76156             6       0.224806           4           6      0.053846
# 28773             8       0.069767          16          11      0.053846
# 128019           11       0.511628          14          11      0.115385
# 85872             5       0.139535          10           5      0.046154
#
#         WindSpeed3pm  Humidity9am  Humidity3pm  Pressure9am  Pressure3pm  \
# 86783       0.218391     0.848485         0.80     0.542149     0.545307
# 76156       0.195402     0.676768         0.37     0.652893     0.653722
# 28773       0.045977     0.979798         0.75     0.814876     0.773463
# 128019      0.103448          NaN          NaN     0.492562     0.585761
# 85872       0.149425     0.585859         0.58     0.581818     0.572816
#
#         Cloud9am  Cloud3pm   Temp9am   Temp3pm  RainToday
# 86783   0.777778     0.875  0.639309  0.566219        0.0
# 76156   0.333333     0.875  0.663067  0.773512        0.0
# 28773   0.888889       NaN  0.311015  0.404990        0.0
# 128019       NaN       NaN  0.403888  0.351248        1.0
# 85872   0.555556     0.250  0.775378  0.685221        0.0

# %%
new_array1 = imputer.transform(X_test)
X_test = pd.DataFrame(data=new_array1, columns=X_test.columns, index=X_test.index)
X_test.head()
# Out:
#         Location   MinTemp   MaxTemp  Rainfall  Evaporation  Sunshine  \
# 86783        8.0  0.695755  0.577735  0.001078     0.017931  0.055944
# 76156       45.0  0.622642  0.788868  0.000000     0.068966  0.615385
# 28773       34.0  0.334906  0.414587  0.000000     0.024552  0.285315
# 128019      15.0  0.455189  0.404990  0.021563     0.027586  0.489510
# 85872        8.0  0.724057  0.700576  0.000000     0.042759  0.741259
#
#         WindGustDir  WindGustSpeed  WindDir9am  WindDir3pm  WindSpeed9am  \
# 86783          10.0       0.341085        10.0        10.0      0.184615
# 76156           6.0       0.224806         4.0         6.0      0.053846
# 28773           8.0       0.069767        16.0        11.0      0.053846
# 128019         11.0       0.511628        14.0        11.0      0.115385
# 85872           5.0       0.139535        10.0         5.0      0.046154
#
#         WindSpeed3pm  Humidity9am  Humidity3pm  Pressure9am  Pressure3pm  \
# 86783       0.218391     0.848485         0.80     0.542149     0.545307
# 76156       0.195402     0.676768         0.37     0.652893     0.653722
# 28773       0.045977     0.979798         0.75     0.814876     0.773463
# 128019      0.103448     0.650505         0.50     0.492562     0.585761
# 85872       0.149425     0.585859         0.58     0.581818     0.572816
#
#         Cloud9am  Cloud3pm   Temp9am   Temp3pm  RainToday
# 86783   0.777778     0.875  0.639309  0.566219        0.0
# 76156   0.333333     0.875  0.663067  0.773512        0.0
# 28773   0.888889     0.750  0.311015  0.404990        0.0
# 128019  0.311111     0.475  0.403888  0.351248        1.0
# 85872   0.555556     0.250  0.775378  0.685221        0.0

# %%
from datetime import datetime
print(datetime.now())
# Out:
# 2021-10-06 22:48:12.983138

# %%
miss_train = (X_train.isnull().sum()).sort_values(ascending=False)
miss_train.isnull().any()
# Out:
# False

# %%
miss_test = (X_train.isnull().sum()).sort_values(ascending=False)
miss_test.isnull().any()
# Out:
# False

# %%
weather_data['RainTomorrow'].value_counts(normalize=True)
# Out:
# 0    0.775819
# 1    0.224181
# Name: RainTomorrow, dtype: float64

# %%
y.value_counts(normalize=True)
# Out:
# 0    0.775819
# 1    0.224181
# Name: RainTomorrow, dtype: float64

# %% [markdown]
# ### Check if any columns has VIF. Note: Correlation is NOT affected by scaling.

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

vif_values = pd.DataFrame(
                {'feature' : X_train.columns,
                 'vif' : [variance_inflation_factor(X_train.values, i) for i  in range(X_train.shape[1])]                   
                }).sort_values(by='vif', ascending=False)
vif_values
# Out:
#           feature         vif
# 15    Pressure3pm  622.410710
# 14    Pressure9am  607.686359
# 19        Temp3pm  532.196377
# 2         MaxTemp  517.274903
# 18        Temp9am  299.128707
# 1         MinTemp   94.523171
# 12    Humidity9am   48.906945
# 13    Humidity3pm   37.937637
# 7   WindGustSpeed   16.518077
# 5        Sunshine   12.320654
# 11   WindSpeed3pm   10.168273
# 17       Cloud3pm    9.030270
# 16       Cloud9am    7.964544
# 10   WindSpeed9am    6.451043
# 9      WindDir3pm    5.828965
# 6     WindGustDir    5.710791
# 4     Evaporation    4.922025
# 8      WindDir9am    4.420192
# 0        Location    3.801963
# 20      RainToday    2.125270
# 3        Rainfall    1.473581

# %%
import seaborn as sns
corr=X_train.iloc[:,:-1].corr()
top_features=corr.index
plt.figure(figsize=(20,20))
sns.heatmap(X_train[top_features].corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
corr
# Out:
#                Location   MinTemp   MaxTemp  Rainfall  Evaporation  Sunshine  \
# Location       1.000000 -0.004129 -0.019469 -0.000126     0.055288 -0.029698
# MinTemp       -0.004129  1.000000  0.734564  0.102600     0.392212  0.063758
# MaxTemp       -0.019469  0.734564  1.000000 -0.075452     0.494551  0.373399
# Rainfall      -0.000126  0.102600 -0.075452  1.000000    -0.054228 -0.200755
# Evaporation    0.055288  0.392212  0.494551 -0.054228     1.000000  0.324636
# Sunshine      -0.029698  0.063758  0.373399 -0.200755     0.324636  1.000000
# WindGustDir   -0.024119 -0.123396 -0.204455  0.046242    -0.083488 -0.099237
# WindGustSpeed  0.077292  0.165542  0.061218  0.129924     0.137452 -0.025261
# WindDir9am    -0.019414 -0.128019 -0.249036  0.063814    -0.143488 -0.139119
# WindDir3pm    -0.009008 -0.157620 -0.182060  0.046845    -0.065575 -0.055385
# WindSpeed9am   0.076528  0.174976  0.015058  0.086970     0.144818  0.012478
# WindSpeed3pm   0.064263  0.167047  0.046967  0.057072     0.095999  0.036072
# Humidity9am   -0.001904 -0.237008 -0.508335  0.222059    -0.425295 -0.407934
# Humidity3pm    0.008140  0.001266 -0.510008  0.252499    -0.334335 -0.511623
# Pressure9am    0.037365 -0.416322 -0.303165 -0.159524    -0.212041  0.028666
# Pressure3pm    0.046703 -0.430757 -0.398765 -0.118120    -0.238308 -0.028205
# Cloud9am      -0.009778  0.034097 -0.272278  0.185116    -0.164579 -0.570110
# Cloud3pm      -0.020941 -0.003369 -0.262932  0.164542    -0.174856 -0.592184
# Temp9am       -0.013710  0.900026  0.886266  0.008851     0.465960  0.235113
# Temp3pm       -0.020743  0.704519  0.978346 -0.080454     0.484304  0.392774
#
#                WindGustDir  WindGustSpeed  WindDir9am  WindDir3pm  \
# Location         -0.024119       0.077292   -0.019414   -0.009008
# MinTemp          -0.123396       0.165542   -0.128019   -0.157620
# MaxTemp          -0.204455       0.061218   -0.249036   -0.182060
# Rainfall          0.046242       0.129924    0.063814    0.046845
# Evaporation      -0.083488       0.137452   -0.143488   -0.065575
# Sunshine         -0.099237      -0.025261   -0.139119   -0.055385
# WindGustDir       1.000000       0.128948    0.355646    0.559019
# WindGustSpeed     0.128948       1.000000   -0.055467    0.127735
# WindDir9am        0.355646      -0.055467    1.000000    0.292123
# WindDir3pm        0.559019       0.127735    0.292123    1.000000
# WindSpeed9am     -0.009144       0.577582   -0.166227    0.025802
# WindSpeed3pm      0.045799       0.641815   -0.032304    0.031482
# Humidity9am       0.069955      -0.207715    0.204894    0.036906
# Humidity3pm       0.083190      -0.027202    0.168988    0.013096
# Pressure9am      -0.123576      -0.437447    0.035433   -0.142618
# Pressure3pm      -0.028315      -0.390969    0.119074   -0.038395
# Cloud9am          0.081534       0.057487    0.110129    0.065522
# Cloud3pm          0.082301       0.098538    0.075579    0.077350
# Temp9am          -0.166374       0.137190   -0.206309   -0.175589
# Temp3pm          -0.222877       0.024864   -0.252500   -0.197711
#
#                WindSpeed9am  WindSpeed3pm  Humidity9am  Humidity3pm  \
# Location           0.076528      0.064263    -0.001904     0.008140
# MinTemp            0.174976      0.167047    -0.237008     0.001266
# MaxTemp            0.015058      0.046967    -0.508335    -0.510008
# Rainfall           0.086970      0.057072     0.222059     0.252499
# Evaporation        0.144818      0.095999    -0.425295    -0.334335
# Sunshine           0.012478      0.036072    -0.407934    -0.511623
# WindGustDir       -0.009144      0.045799     0.069955     0.083190
# WindGustSpeed      0.577582      0.641815    -0.207715    -0.027202
# WindDir9am        -0.166227     -0.032304     0.204894     0.168988
# WindDir3pm         0.025802      0.031482     0.036906     0.013096
# WindSpeed9am       1.000000      0.514815    -0.268786    -0.035291
# WindSpeed3pm       0.514815      1.000000    -0.147211     0.009088
# Humidity9am       -0.268786     -0.147211     1.000000     0.667997
# Humidity3pm       -0.035291      0.009088     0.667997     1.000000
# Pressure9am       -0.230648     -0.280089     0.141380    -0.016830
# Pressure3pm       -0.180271     -0.246014     0.188377     0.063164
# Cloud9am           0.012844      0.043739     0.379004     0.443683
# Cloud3pm           0.044091      0.026531     0.309022     0.452467
# Temp9am            0.128283      0.157279    -0.476625    -0.229658
# Temp3pm            0.004592      0.028208    -0.501655    -0.562002
#
#                Pressure9am  Pressure3pm  Cloud9am  Cloud3pm   Temp9am  \
# Location          0.037365     0.046703 -0.009778 -0.020941 -0.013710
# MinTemp          -0.416322    -0.430757  0.034097 -0.003369  0.900026
# MaxTemp          -0.303165    -0.398765 -0.272278 -0.262932  0.886266
# Rainfall         -0.159524    -0.118120  0.185116  0.164542  0.008851
# Evaporation      -0.212041    -0.238308 -0.164579 -0.174856  0.465960
# Sunshine          0.028666    -0.028205 -0.570110 -0.592184  0.235113
# WindGustDir      -0.123576    -0.028315  0.081534  0.082301 -0.166374
# WindGustSpeed    -0.437447    -0.390969  0.057487  0.098538  0.137190
# WindDir9am        0.035433     0.119074  0.110129  0.075579 -0.206309
# WindDir3pm       -0.142618    -0.038395  0.065522  0.077350 -0.175589
# WindSpeed9am     -0.230648    -0.180271  0.012844  0.044091  0.128283
# WindSpeed3pm     -0.280089    -0.246014  0.043739  0.026531  0.157279
# Humidity9am       0.141380     0.188377  0.379004  0.309022 -0.476625
# Humidity3pm      -0.016830     0.063164  0.443683  0.452467 -0.229658
# Pressure9am       1.000000     0.959063 -0.099011 -0.122407 -0.391031
# Pressure3pm       0.959063     1.000000 -0.037697 -0.064109 -0.441578
# Cloud9am         -0.099011    -0.037697  1.000000  0.593670 -0.144388
# Cloud3pm         -0.122407    -0.064109  0.593670  1.000000 -0.133020
# Temp9am          -0.391031    -0.441578 -0.144388 -0.133020  1.000000
# Temp3pm          -0.261046    -0.364977 -0.285793 -0.296268  0.857182
#
#                 Temp3pm
# Location      -0.020743
# MinTemp        0.704519
# MaxTemp        0.978346
# Rainfall      -0.080454
# Evaporation    0.484304
# Sunshine       0.392774
# WindGustDir   -0.222877
# WindGustSpeed  0.024864
# WindDir9am    -0.252500
# WindDir3pm    -0.197711
# WindSpeed9am   0.004592
# WindSpeed3pm   0.028208
# Humidity9am   -0.501655
# Humidity3pm   -0.562002
# Pressure9am   -0.261046
# Pressure3pm   -0.364977
# Cloud9am      -0.285793
# Cloud3pm      -0.296268
# Temp9am        0.857182
# Temp3pm        1.000000

# %%
for row in corr.index:
    for col in corr.columns:
        if abs(corr.loc[row, col]) > 0.7 and row != col:
            print(row, col, round(corr.loc[row, col], 4))
# Out:
# MinTemp MaxTemp 0.7346
# MinTemp Temp9am 0.9
# MinTemp Temp3pm 0.7045
# MaxTemp MinTemp 0.7346
# MaxTemp Temp9am 0.8863
# MaxTemp Temp3pm 0.9783
# Pressure9am Pressure3pm 0.9591
# Pressure3pm Pressure9am 0.9591
# Temp9am MinTemp 0.9
# Temp9am MaxTemp 0.8863
# Temp9am Temp3pm 0.8572
# Temp3pm MinTemp 0.7045
# Temp3pm MaxTemp 0.9783
# Temp3pm Temp9am 0.8572

# %%
X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((99535, 21), (99535,), (42658, 21), (42658,))

# %%
X_train.head()
# Out:
#         Location   MinTemp   MaxTemp  Rainfall  Evaporation  Sunshine  \
# 106233       1.0  0.398585  0.357006  0.024798     0.027586  0.482517
# 96877        0.0  0.530660  0.625720  0.000000     0.053517  0.837762
# 109078      47.0  0.353774  0.639155  0.000539     0.041103  0.675524
# 37945       43.0  0.683962  0.761996  0.000000     0.052414  0.685315
# 49491       40.0  0.341981  0.650672  0.000000     0.043310  0.742657
#
#         WindGustDir  WindGustSpeed  WindDir9am  WindDir3pm  WindSpeed9am  \
# 106233         17.0       0.341085        16.0        14.0      0.338462
# 96877           1.0       0.124031         3.0        15.0      0.046154
# 109078          3.0       0.224806         4.0         3.0      0.100000
# 37945           2.0       0.395349         1.0         1.0      0.169231
# 49491          15.0       0.255814        17.0        15.0      0.000000
#
#         WindSpeed3pm  Humidity9am  Humidity3pm  Pressure9am  Pressure3pm  \
# 106233      0.321839     0.515152         0.55     0.471074     0.542071
# 96877       0.080460     0.484848         0.30     0.676033     0.676375
# 109078      0.195402     0.525253         0.27     0.707438     0.695793
# 37945       0.149425     0.525253         0.33     0.598347     0.600324
# 49491       0.195402     0.464646         0.25     0.525620     0.514563
#
#         Cloud9am  Cloud3pm   Temp9am   Temp3pm  RainToday
# 106233  0.666667      0.75  0.401728  0.337812        1.0
# 96877   0.400000      0.55  0.602592  0.625720        0.0
# 109078  0.622222      0.85  0.611231  0.639155        0.0
# 37945   0.222222      0.50  0.710583  0.750480        0.0
# 49491   0.377778      0.10  0.552916  0.641075        0.0

# %%
X_test.head()
# Out:
#         Location   MinTemp   MaxTemp  Rainfall  Evaporation  Sunshine  \
# 86783        8.0  0.695755  0.577735  0.001078     0.017931  0.055944
# 76156       45.0  0.622642  0.788868  0.000000     0.068966  0.615385
# 28773       34.0  0.334906  0.414587  0.000000     0.024552  0.285315
# 128019      15.0  0.455189  0.404990  0.021563     0.027586  0.489510
# 85872        8.0  0.724057  0.700576  0.000000     0.042759  0.741259
#
#         WindGustDir  WindGustSpeed  WindDir9am  WindDir3pm  WindSpeed9am  \
# 86783          10.0       0.341085        10.0        10.0      0.184615
# 76156           6.0       0.224806         4.0         6.0      0.053846
# 28773           8.0       0.069767        16.0        11.0      0.053846
# 128019         11.0       0.511628        14.0        11.0      0.115385
# 85872           5.0       0.139535        10.0         5.0      0.046154
#
#         WindSpeed3pm  Humidity9am  Humidity3pm  Pressure9am  Pressure3pm  \
# 86783       0.218391     0.848485         0.80     0.542149     0.545307
# 76156       0.195402     0.676768         0.37     0.652893     0.653722
# 28773       0.045977     0.979798         0.75     0.814876     0.773463
# 128019      0.103448     0.650505         0.50     0.492562     0.585761
# 85872       0.149425     0.585859         0.58     0.581818     0.572816
#
#         Cloud9am  Cloud3pm   Temp9am   Temp3pm  RainToday
# 86783   0.777778     0.875  0.639309  0.566219        0.0
# 76156   0.333333     0.875  0.663067  0.773512        0.0
# 28773   0.888889     0.750  0.311015  0.404990        0.0
# 128019  0.311111     0.475  0.403888  0.351248        1.0
# 85872   0.555556     0.250  0.775378  0.685221        0.0

# %%
#Lets save train and test data at this point for later use

train = pd.concat([X_train, y_train], axis=1)
train.to_csv('data_train_full.csv', index=False)

test = pd.concat([X_test, y_test], axis=1)
test.to_csv('data_test_full.csv', index=False)
