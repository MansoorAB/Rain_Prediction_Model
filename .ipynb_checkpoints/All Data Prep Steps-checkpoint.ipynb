# %% [markdown]
# ## Let's check the environment first thing

# %%
import sys
sys.executable
# Out:
# 'C:\\Users\\Mansoor\\anaconda3\\envs\\rainfall_prediction\\python.exe'

# %%
run_sample = False
sample_pct = 0.10

# %% [markdown]
# ### Read and Display the data

# %%
import pandas as pd

pd.set_option('display.max_columns', None)

weather_data = pd.read_csv('weatherAUS.csv')
weather_data.head()
# Out:
#         Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  12/1/2008   Albury     13.4     22.9       0.6          NaN       NaN
# 1  12/2/2008   Albury      7.4     25.1       0.0          NaN       NaN
# 2  12/3/2008   Albury     12.9     25.7       0.0          NaN       NaN
# 3  12/4/2008   Albury      9.2     28.0       0.0          NaN       NaN
# 4  12/5/2008   Albury     17.5     32.3       1.0          NaN       NaN
#
#   WindGustDir  WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  \
# 0           W           44.0          W        WNW          20.0
# 1         WNW           44.0        NNW        WSW           4.0
# 2         WSW           46.0          W        WSW          19.0
# 3          NE           24.0         SE          E          11.0
# 4           W           41.0        ENE         NW           7.0
#
#    WindSpeed3pm  Humidity9am  Humidity3pm  Pressure9am  Pressure3pm  Cloud9am  \
# 0          24.0         71.0         22.0       1007.7       1007.1       8.0
# 1          22.0         44.0         25.0       1010.6       1007.8       NaN
# 2          26.0         38.0         30.0       1007.6       1008.7       NaN
# 3           9.0         45.0         16.0       1017.6       1012.8       NaN
# 4          20.0         82.0         33.0       1010.8       1006.0       7.0
#
#    Cloud3pm  Temp9am  Temp3pm RainToday RainTomorrow
# 0       NaN     16.9     21.8        No           No
# 1       NaN     17.2     24.3        No           No
# 2       2.0     21.0     23.2        No           No
# 3       NaN     18.1     26.5        No           No
# 4       8.0     17.8     29.7        No           No

# %%
weather_data.describe().T
# Out:
#                   count         mean        std    min     25%     50%  \
# MinTemp        141556.0    12.186400   6.403283   -8.5     7.6    12.0
# MaxTemp        141871.0    23.226784   7.117618   -4.8    17.9    22.6
# Rainfall       140787.0     2.349974   8.465173    0.0     0.0     0.0
# Evaporation     81350.0     5.469824   4.188537    0.0     2.6     4.8
# Sunshine        74377.0     7.624853   3.781525    0.0     4.9     8.5
# WindGustSpeed  132923.0    39.984292  13.588801    6.0    31.0    39.0
# WindSpeed9am   140845.0    14.001988   8.893337    0.0     7.0    13.0
# WindSpeed3pm   139563.0    18.637576   8.803345    0.0    13.0    19.0
# Humidity9am    140419.0    68.843810  19.051293    0.0    57.0    70.0
# Humidity3pm    138583.0    51.482606  20.797772    0.0    37.0    52.0
# Pressure9am    128179.0  1017.653758   7.105476  980.5  1012.9  1017.6
# Pressure3pm    128212.0  1015.258204   7.036677  977.1  1010.4  1015.2
# Cloud9am        88536.0     4.437189   2.887016    0.0     1.0     5.0
# Cloud3pm        85099.0     4.503167   2.720633    0.0     2.0     5.0
# Temp9am        141289.0    16.987509   6.492838   -7.2    12.3    16.7
# Temp3pm        139467.0    21.687235   6.937594   -5.4    16.6    21.1
#
#                   75%     max
# MinTemp          16.8    33.9
# MaxTemp          28.2    48.1
# Rainfall          0.8   371.0
# Evaporation       7.4   145.0
# Sunshine         10.6    14.5
# WindGustSpeed    48.0   135.0
# WindSpeed9am     19.0   130.0
# WindSpeed3pm     24.0    87.0
# Humidity9am      83.0   100.0
# Humidity3pm      66.0   100.0
# Pressure9am    1022.4  1041.0
# Pressure3pm    1020.0  1039.6
# Cloud9am          7.0     9.0
# Cloud3pm          7.0     9.0
# Temp9am          21.6    40.2
# Temp3pm          26.4    46.7

# %%
# Date column is of no relevance here, hence dropping. It has unique value for each record

weather_data.drop('Date', axis=1, inplace=True)

# %% [markdown]
# ## Step 1 – Exploratory Data Analysis

# %%
weather_data.shape
# Out:
# (142193, 22)

# %%
weather_data['RainTomorrow'].value_counts()
# Out:
# No     110316
# Yes     31877
# Name: RainTomorrow, dtype: int64

# %%
weather_data['RainTomorrow'].value_counts(normalize=True)
# Out:
# No     0.775819
# Yes    0.224181
# Name: RainTomorrow, dtype: float64

# %%
weather_sample = weather_data.sample(frac=sample_pct)
weather_sample['RainTomorrow'].value_counts(normalize=True)
# Out:
# No     0.775441
# Yes    0.224559
# Name: RainTomorrow, dtype: float64

# %%
weather_data.shape, weather_sample.shape
# Out:
# ((142193, 22), (14219, 22))

# %%
weather_data.shape
# Out:
# (142193, 22)

# %%
# For testing purpose, run with 10% of data
if run_sample:
    weather_data = weather_sample.copy()

# %%
weather_data.shape
# Out:
# (14219, 22)

# %%
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(8, 5))

weather_data['RainTomorrow'].value_counts(normalize=True).plot(kind='bar', color = ['darkgrey', 'green'], alpha=0.8, rot=0)
plt.title('RainTomorrow - No Rain vs Rain')
plt.show()

# %%
from collections import Counter

Counter(weather_data['RainTomorrow'])
# Out:
# Counter({'Yes': 3193, 'No': 11026})

# %% [markdown]
# ### Let's check for missing values

# %%
miss_pct = (weather_data.isnull().sum() * 100 / len(weather_data)).sort_values(ascending=False)
miss_sum = (weather_data.isnull().sum()).sort_values(ascending=False)

missing = pd.concat([miss_sum, miss_pct], axis=1, keys=['Total', 'Percent'])
missing
# Out:
#                Total    Percent
# Sunshine        6684  47.007525
# Evaporation     5977  42.035305
# Cloud3pm        5716  40.199733
# Cloud9am        5335  37.520219
# Pressure9am     1359   9.557634
# Pressure3pm     1358   9.550601
# WindDir9am       979   6.885154
# WindGustDir      923   6.491314
# WindGustSpeed    915   6.435052
# WindDir3pm       375   2.637316
# Humidity3pm      371   2.609185
# Temp3pm          286   2.011393
# WindSpeed3pm     262   1.842605
# Humidity9am      164   1.153386
# WindSpeed9am     136   0.956467
# RainToday        134   0.942401
# Rainfall         134   0.942401
# Temp9am           77   0.541529
# MinTemp           59   0.414938
# MaxTemp           34   0.239117
# Location           0   0.000000
# RainTomorrow       0   0.000000

# %%
# nan_columns = missing[missing['Percent'] >= 35].index.tolist()
# nan_columns

# %% [markdown]
# ## Step 2 – Feature Engineering

# %% [markdown]
# > We need to predict 'RainTomorrow' based on other dependent features. Let's convert RainToday and RainTomorrow from Yes/No to 1/0

# %%
weather_data['RainToday'].replace({'Yes': 1, 'No': 0}, inplace=True)
weather_data['RainTomorrow'].replace({'Yes': 1, 'No': 0}, inplace=True)

weather_data.head(20)
# Out:
#              Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 28189        Richmond     14.0     24.4      17.2          2.0       NaN
# 132492     Launceston      3.6     16.5       0.2          NaN       NaN
# 98986    MountGambier     10.0     14.9       0.2          4.2       6.0
# 78069        Watsonia      5.5     12.7       2.6          1.4       1.0
# 123123     SalmonGums     10.2     16.6       9.4          NaN       NaN
# 116489   PerthAirport     14.8     34.9       0.0         10.6      12.2
# 59693         Bendigo      1.8     18.2       0.0          NaN       NaN
# 4433    BadgerysCreek     14.5     21.2       5.4          NaN       NaN
# 73916        Portland     12.0     17.6       0.0          0.8       6.8
# 56280        Ballarat     13.7     20.2       2.8          NaN       NaN
# 83474        Brisbane     12.1     25.8       0.0          4.2      10.5
# 77783        Watsonia     14.3     21.9       0.0         10.0       3.3
# 43247      Wollongong     14.2     19.3       0.0          NaN       NaN
# 126641        Walpole     11.9     17.8       4.8          NaN       NaN
# 4767    BadgerysCreek     17.1     27.9      10.8          NaN       NaN
# 98600    MountGambier     10.2     20.4       0.0          3.2       2.2
# 26474         Penrith     11.4     25.5       0.0          NaN       NaN
# 54220        Ballarat      2.0     13.3       0.0          NaN       NaN
# 137636         Darwin     22.3     31.8       0.0          6.2      10.9
# 119380          Perth     14.1     24.2       0.2          2.6       9.9
#
#        WindGustDir  WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  \
# 28189          SSE           30.0        SSW         NE           2.0
# 132492           W           26.0         NW          W           7.0
# 98986          WNW           76.0        NNW        WSW          33.0
# 78069          WSW           28.0          W         SW          11.0
# 123123          NE           33.0        NNE          N          20.0
# 116489         SSW           39.0         SW         SW           9.0
# 59693          SSE           20.0        SSE          N           9.0
# 4433           SSE           19.0        SSW        ESE           7.0
# 73916            E           26.0        SSE        ESE           7.0
# 56280          NNE           57.0          N        NNE          31.0
# 83474           NE           20.0         SW        NNE           4.0
# 77783           SW           24.0        SSW        SSW           7.0
# 43247            S           39.0         SW          S          17.0
# 126641          NW           31.0         NW        WNW          13.0
# 4767           ESE           37.0        SSW        ENE           4.0
# 98600          NNW           57.0          N         NW          20.0
# 26474          WNW           17.0        ENE        NNE           2.0
# 54220            N           26.0          E          N           2.0
# 137636          SE           44.0        ESE        ENE          20.0
# 119380          SW           28.0        SSE         SW          11.0
#
#         WindSpeed3pm  Humidity9am  Humidity3pm  Pressure9am  Pressure3pm  \
# 28189            7.0         91.0         69.0       1013.2       1010.9
# 132492          11.0         72.0         41.0          NaN          NaN
# 98986           37.0         88.0         55.0       1006.2       1011.1
# 78069           15.0        100.0         86.0       1019.4       1020.4
# 123123           7.0         80.0         83.0          NaN          NaN
# 116489          28.0         36.0         19.0       1016.7       1014.5
# 59693            9.0         86.0         47.0       1026.3       1023.5
# 4433             9.0         92.0         78.0       1030.7       1028.5
# 73916           11.0         64.0         53.0       1036.8       1034.4
# 56280           35.0        100.0         79.0       1014.9       1011.0
# 83474            7.0         69.0         51.0       1023.3       1018.4
# 77783           13.0        100.0         71.0       1020.4       1016.6
# 43247           31.0         53.0         66.0          NaN       1022.9
# 126641          11.0        100.0         96.0       1019.9       1018.5
# 4767            13.0         95.0         43.0       1022.6       1020.3
# 98600           39.0         60.0         61.0       1007.2       1001.6
# 26474            6.0          NaN          NaN          NaN          NaN
# 54220           15.0         98.0         68.0       1019.5       1017.8
# 137636          20.0         58.0         36.0       1011.9       1008.2
# 119380          15.0         81.0         48.0       1020.1       1017.9
#
#         Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  RainTomorrow
# 28189        NaN       NaN     17.4     20.5        1.0             1
# 132492       NaN       NaN      9.6     16.2        0.0             0
# 98986        8.0       6.0     13.7     13.1        0.0             1
# 78069        7.0       6.0      8.1     11.4        1.0             1
# 123123       NaN       NaN     13.0     15.8        1.0             1
# 116489       0.0       0.0     27.6     34.2        0.0             0
# 59693        NaN       NaN      9.6     17.4        0.0             0
# 4433         NaN       NaN     16.6     19.1        1.0             1
# 73916        8.0       3.0     13.9     16.0        0.0             0
# 56280        8.0       5.0     15.0     18.4        1.0             1
# 83474        1.0       1.0     19.3     24.2        0.0             0
# 77783        8.0       8.0     14.7     20.7        0.0             0
# 43247        NaN       7.0     18.0     18.1        0.0             0
# 126641       NaN       NaN     13.9     16.3        1.0             1
# 4767         NaN       NaN     21.0     27.4        1.0             0
# 98600        8.0       5.0     15.4     17.5        0.0             1
# 26474        NaN       NaN     17.5     25.1        0.0             0
# 54220        4.0       7.0      7.3     12.5        0.0             0
# 137636       2.0       5.0     24.8     31.2        0.0             0
# 119380       3.0       1.0     18.6     23.4        0.0             0

# %%
weather_data.shape
# Out:
# (14219, 22)

# %% [markdown]
# ### Train Test Split

# %%
from sklearn.model_selection import train_test_split

# %%
y = weather_data['RainTomorrow']
X = weather_data.drop('RainTomorrow', axis=1)
X.shape
# Out:
# (14219, 21)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=10)
X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((9953, 21), (9953,), (4266, 21), (4266,))

# %%
142193* .1 * .7
# Out:
# 9953.51

# %%
miss_pct = (X_train.isnull().sum() * 100 / len(X_train)).sort_values(ascending=False)
miss_sum = (X_train.isnull().sum()).sort_values(ascending=False)

missing = pd.concat([miss_sum, miss_pct], axis=1, keys=['Total', 'Percent'])
missing
# Out:
#                Total    Percent
# Sunshine        4676  46.980810
# Evaporation     4192  42.117954
# Cloud3pm        4018  40.369738
# Cloud9am        3775  37.928263
# Pressure3pm      954   9.585050
# Pressure9am      950   9.544861
# WindDir9am       657   6.601025
# WindGustDir      626   6.289561
# WindGustSpeed    619   6.219230
# Humidity3pm      260   2.612278
# WindDir3pm       251   2.521853
# Temp3pm          199   1.999397
# WindSpeed3pm     170   1.708028
# Humidity9am      115   1.155431
# RainToday         97   0.974581
# Rainfall          97   0.974581
# WindSpeed9am      90   0.904250
# Temp9am           54   0.542550
# MinTemp           33   0.331558
# MaxTemp           22   0.221039
# Location           0   0.000000

# %% [markdown]
# ### Label Encoding the Categorical features

# %%
from sklearn.preprocessing import LabelEncoder
import numpy as np

class LabelEncoderExt(object):
    def __init__(self):
        """
        It differs from LabelEncoder by handling new classes and providing a value for it [Unknown]
        Unknown will be added in fit and transform will take care of new item. It gives unknown class id
        """
        self.label_encoder = LabelEncoder()
        # self.classes_ = self.label_encoder.classes_

    def fit(self, data_list):
        """
        This will fit the encoder for all the unique values and introduce unknown value
        :param data_list: A list of string
        :return: self
        """
        self.label_encoder = self.label_encoder.fit(list(data_list) + ['Unknown'])
        self.classes_ = self.label_encoder.classes_

        return self

    def transform(self, data_list):
        """
        This will transform the data_list to id list where the new values get assigned to Unknown class
        :param data_list:
        :return:
        """
        new_data_list = list(data_list)
        for unique_item in np.unique(data_list):
            if unique_item not in self.label_encoder.classes_:
                new_data_list = ['Unknown' if x==unique_item else x for x in new_data_list]

        return self.label_encoder.transform(new_data_list)

# %%
categorical_columns = X_train.select_dtypes(include=['object']).columns
categorical_columns, len(categorical_columns)
# Out:
# (Index(['Location', 'WindGustDir', 'WindDir9am', 'WindDir3pm'], dtype='object'),
#  4)

# %%
numerical_columns = X_train.select_dtypes(exclude=['object']).columns
numerical_columns, len(numerical_columns)
# Out:
# (Index(['MinTemp', 'MaxTemp', 'Rainfall', 'Evaporation', 'Sunshine',
#         'WindGustSpeed', 'WindSpeed9am', 'WindSpeed3pm', 'Humidity9am',
#         'Humidity3pm', 'Pressure9am', 'Pressure3pm', 'Cloud9am', 'Cloud3pm',
#         'Temp9am', 'Temp3pm', 'RainToday'],
#        dtype='object'),
#  17)

# %%
X_train[categorical_columns]
# Out:
#              Location WindGustDir WindDir9am WindDir3pm
# 12602           Moree           E        ESE          E
# 106853         Albany         NaN        NNW        WSW
# 11728    CoffsHarbour          SW        SSW        SSE
# 55878        Ballarat           W          N          W
# 12495           Moree           E          E        SSW
# ...               ...         ...        ...        ...
# 25737         Penrith         ESE        ENE          E
# 136841         Darwin          NW        WSW         NW
# 33371   SydneyAirport           S        SSW         SW
# 49588     Tuggeranong         NNW        NaN        WNW
# 96041        Adelaide         SSE        SSW         SE
#
# [9953 rows x 4 columns]

# %%
X_train[categorical_columns].isnull().sum()
# Out:
# Location         0
# WindGustDir    626
# WindDir9am     657
# WindDir3pm     251
# dtype: int64

# %%
from pickle import dump
lencoders = {}

for col in categorical_columns:
    lencoders[col] = LabelEncoderExt()
    lencoders[col].fit(X_train[col])
    X_train[col] = lencoders[col].transform(X_train[col].astype('str'))
    X_test[col] = lencoders[col].transform(X_test[col].astype('str'))
    
dump(lencoders, open('labelencoder.pkl', 'wb'))

# %%
X_train[categorical_columns].isnull().sum()
# Out:
# Location       0
# WindGustDir    0
# WindDir9am     0
# WindDir3pm     0
# dtype: int64

# %%
X_train[categorical_columns]
# Out:
#         Location  WindGustDir  WindDir9am  WindDir3pm
# 12602         21            0           2           0
# 106853         1           17           6          16
# 11728         11           12          11          10
# 55878          5           14           3          14
# 12495         21            0           0          11
# ...          ...          ...         ...         ...
# 25737         30            2           1           0
# 136841        13            7          16           7
# 33371         38            8          11          12
# 49588         40            6          17          15
# 96041          0           10          11           9
#
# [9953 rows x 4 columns]

# %% [markdown]
# ### WindGustDir had 6585 missing values on full data, did they get encoded with 16? Lets check!

# %%
X_train['WindGustDir'].value_counts().sort_index()[-1:]
# Out:
# 17    626
# Name: WindGustDir, dtype: int64

# %%
for col in categorical_columns:
    #print(col)
    print(X_train[col].value_counts().sort_index()[-1:])
    print('--' * 60)
# Out:
# 49    188
# Name: Location, dtype: int64
# ------------------------------------------------------------------------------------------------------------------------
# 17    626
# Name: WindGustDir, dtype: int64
# ------------------------------------------------------------------------------------------------------------------------
# 17    657
# Name: WindDir9am, dtype: int64
# ------------------------------------------------------------------------------------------------------------------------
# 17    251
# Name: WindDir3pm, dtype: int64
# ------------------------------------------------------------------------------------------------------------------------

# %%
X_train['WindDir3pm'].value_counts().sort_index()
# Out:
# 0     587
# 1     495
# 2     563
# 3     597
# 4     624
# 5     414
# 6     557
# 7     590
# 8     644
# 9     786
# 10    656
# 11    556
# 12    680
# 14    750
# 15    596
# 16    607
# 17    251
# Name: WindDir3pm, dtype: int64

# %% [markdown]
# > WindDir3pm, WindDir9am, WindGustDir - For these features, the value of 16 would imply a NaN, so this has to be replaced during Impuation of missing values.

# %% [markdown]
# ### Lets use KNN Imputer to impute missing values, but before that we need to normalize the data

# %%
X_train.isnull().sum()
# Out:
# Location            0
# MinTemp            33
# MaxTemp            22
# Rainfall           97
# Evaporation      4192
# Sunshine         4676
# WindGustDir         0
# WindGustSpeed     619
# WindDir9am          0
# WindDir3pm          0
# WindSpeed9am       90
# WindSpeed3pm      170
# Humidity9am       115
# Humidity3pm       260
# Pressure9am       950
# Pressure3pm       954
# Cloud9am         3775
# Cloud3pm         4018
# Temp9am            54
# Temp3pm           199
# RainToday          97
# dtype: int64

# %%
X_train.head()
# Out:
#         Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 12602         21     18.7     30.7       0.2          3.0       5.2
# 106853         1      8.9     16.4       6.4          1.4       8.3
# 11728         11     23.7     27.7       0.0          NaN       NaN
# 55878          5     14.3     23.6       0.0          NaN       NaN
# 12495         21      4.8     20.9       0.0          3.8      10.0
#
#         WindGustDir  WindGustSpeed  WindDir9am  WindDir3pm  WindSpeed9am  \
# 12602             0           48.0           2           0          26.0
# 106853           17            NaN           6          16          11.0
# 11728            12           43.0          11          10          28.0
# 55878            14           52.0           3          14          28.0
# 12495             0           28.0           0          11          17.0
#
#         WindSpeed3pm  Humidity9am  Humidity3pm  Pressure9am  Pressure3pm  \
# 12602           15.0         47.0         42.0       1017.6       1015.5
# 106853           6.0         72.0         58.0       1023.3       1019.2
# 11728           17.0         85.0         78.0       1017.3       1016.2
# 55878           28.0         75.0         53.0       1009.6       1008.5
# 12495            9.0         62.0         34.0       1024.8       1021.0
#
#         Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday
# 12602        2.0       8.0     26.8     29.7        0.0
# 106853       6.0       3.0     11.7     15.8        1.0
# 11728        8.0       4.0     23.9     25.2        0.0
# 55878        7.0       8.0     16.7     22.9        0.0
# 12495        6.0       0.0     13.4     20.3        0.0

# %%
from sklearn.preprocessing import MinMaxScaler
import numpy as np

from pickle import dump, load

scaler = {}

for col in numerical_columns:
    scaler[col] = MinMaxScaler()
    X_train[col] = scaler[col].fit_transform(np.array(X_train[col]).reshape(-1, 1))
    X_test[col]  = scaler[col].transform(np.array(X_test[col]).reshape(-1, 1))

dump(scaler, open('scaler.pkl', 'wb'))

# %%
X_train.head()
# Out:
#         Location   MinTemp   MaxTemp  Rainfall  Evaporation  Sunshine  \
# 12602         21  0.703209  0.677355  0.001142     0.050676  0.371429
# 106853         1  0.441176  0.390782  0.036530     0.023649  0.592857
# 11728         11  0.836898  0.617234  0.000000          NaN       NaN
# 55878          5  0.585561  0.535070  0.000000          NaN       NaN
# 12495         21  0.331551  0.480962  0.000000     0.064189  0.714286
#
#         WindGustDir  WindGustSpeed  WindDir9am  WindDir3pm  WindSpeed9am  \
# 12602             0       0.344538           2           0      0.412698
# 106853           17            NaN           6          16      0.174603
# 11728            12       0.302521          11          10      0.444444
# 55878            14       0.378151           3          14      0.444444
# 12495             0       0.176471           0          11      0.269841
#
#         WindSpeed3pm  Humidity9am  Humidity3pm  Pressure9am  Pressure3pm  \
# 12602       0.192308     0.453608     0.414141     0.590580     0.632616
# 106853      0.076923     0.711340     0.575758     0.693841     0.698925
# 11728       0.217949     0.845361     0.777778     0.585145     0.645161
# 55878       0.358974     0.742268     0.525253     0.445652     0.507168
# 12495       0.115385     0.608247     0.333333     0.721014     0.731183
#
#         Cloud9am  Cloud3pm   Temp9am   Temp3pm  RainToday
# 12602      0.250     1.000  0.749420  0.674747        0.0
# 106853     0.750     0.375  0.399072  0.393939        1.0
# 11728      1.000     0.500  0.682135  0.583838        0.0
# 55878      0.875     1.000  0.515081  0.537374        0.0
# 12495      0.750     0.000  0.438515  0.484848        0.0

# %%
from datetime import datetime
print(datetime.now())
# Out:
# 2021-10-06 10:48:38.998508

# %%
from sklearn.impute import KNNImputer
import numpy as np

imputer = KNNImputer(n_neighbors=5, weights='uniform', missing_values=np.nan)
new_array = imputer.fit_transform(X_train)
X_train = pd.DataFrame(data=new_array, columns=X_train.columns, index=X_train.index)
X_train.head()
# Out:
#         Location   MinTemp   MaxTemp  Rainfall  Evaporation  Sunshine  \
# 12602       21.0  0.703209  0.677355  0.001142     0.050676  0.371429
# 106853       1.0  0.441176  0.390782  0.036530     0.023649  0.592857
# 11728       11.0  0.836898  0.617234  0.000000     0.072297  0.455714
# 55878        5.0  0.585561  0.535070  0.000000     0.118243  0.601429
# 12495       21.0  0.331551  0.480962  0.000000     0.064189  0.714286
#
#         WindGustDir  WindGustSpeed  WindDir9am  WindDir3pm  WindSpeed9am  \
# 12602           0.0       0.344538         2.0         0.0      0.412698
# 106853         17.0       0.213445         6.0        16.0      0.174603
# 11728          12.0       0.302521        11.0        10.0      0.444444
# 55878          14.0       0.378151         3.0        14.0      0.444444
# 12495           0.0       0.176471         0.0        11.0      0.269841
#
#         WindSpeed3pm  Humidity9am  Humidity3pm  Pressure9am  Pressure3pm  \
# 12602       0.192308     0.453608     0.414141     0.590580     0.632616
# 106853      0.076923     0.711340     0.575758     0.693841     0.698925
# 11728       0.217949     0.845361     0.777778     0.585145     0.645161
# 55878       0.358974     0.742268     0.525253     0.445652     0.507168
# 12495       0.115385     0.608247     0.333333     0.721014     0.731183
#
#         Cloud9am  Cloud3pm   Temp9am   Temp3pm  RainToday
# 12602      0.250     1.000  0.749420  0.674747        0.0
# 106853     0.750     0.375  0.399072  0.393939        1.0
# 11728      1.000     0.500  0.682135  0.583838        0.0
# 55878      0.875     1.000  0.515081  0.537374        0.0
# 12495      0.750     0.000  0.438515  0.484848        0.0

# %%
X_train.shape
# Out:
# (9953, 21)

# %%
X_test.head()
# Out:
#         Location   MinTemp   MaxTemp  Rainfall  Evaporation  Sunshine  \
# 141820        41  0.417112  0.478958  0.000000          NaN       NaN
# 14561         21  0.740642  0.779559  0.000000          NaN       NaN
# 77240         45  0.671123  0.454910  0.000000     0.155405  0.142857
# 123438        36  0.352941  0.462926  0.000000          NaN       NaN
# 82855          7  0.609626  0.649299  0.035388     0.094595  0.857143
#
#         WindGustDir  WindGustSpeed  WindDir9am  WindDir3pm  WindSpeed9am  \
# 141820           17            NaN          17          17           NaN
# 14561             4       0.361345           0           9      0.476190
# 77240             3       0.344538          14          12      0.111111
# 123438           15       0.252101          15          14      0.301587
# 82855             1       0.109244          16           1      0.063492
#
#         WindSpeed3pm  Humidity9am  Humidity3pm  Pressure9am  Pressure3pm  \
# 141820           NaN     0.690722     0.343434     0.717391     0.734767
# 14561       0.192308     0.381443     0.191919     0.545290     0.555556
# 77240       0.089744     0.371134     0.707071     0.538043     0.639785
# 123438      0.243590     0.731959     0.525253          NaN          NaN
# 82855       0.141026     0.628866     0.484848     0.528986     0.591398
#
#         Cloud9am  Cloud3pm   Temp9am   Temp3pm  RainToday
# 141820     0.750     0.125  0.382831  0.472727        0.0
# 14561        NaN       NaN  0.730858  0.763636        0.0
# 77240      0.875     0.875  0.580046  0.410101        0.0
# 123438       NaN       NaN  0.422274  0.464646        0.0
# 82855      0.000     0.125  0.672854  0.618182        1.0

# %%
new_array1 = imputer.transform(X_test)
X_test = pd.DataFrame(data=new_array1, columns=X_test.columns, index=X_test.index)
X_test.head()
# Out:
#         Location   MinTemp   MaxTemp  Rainfall  Evaporation  Sunshine  \
# 141820      41.0  0.417112  0.478958  0.000000     0.116216  0.542857
# 14561       21.0  0.740642  0.779559  0.000000     0.088514  0.588571
# 77240       45.0  0.671123  0.454910  0.000000     0.155405  0.142857
# 123438      36.0  0.352941  0.462926  0.000000     0.054054  0.410000
# 82855        7.0  0.609626  0.649299  0.035388     0.094595  0.857143
#
#         WindGustDir  WindGustSpeed  WindDir9am  WindDir3pm  WindSpeed9am  \
# 141820         17.0       0.255462        17.0        17.0      0.165079
# 14561           4.0       0.361345         0.0         9.0      0.476190
# 77240           3.0       0.344538        14.0        12.0      0.111111
# 123438         15.0       0.252101        15.0        14.0      0.301587
# 82855           1.0       0.109244        16.0         1.0      0.063492
#
#         WindSpeed3pm  Humidity9am  Humidity3pm  Pressure9am  Pressure3pm  \
# 141820      0.243590     0.690722     0.343434     0.717391     0.734767
# 14561       0.192308     0.381443     0.191919     0.545290     0.555556
# 77240       0.089744     0.371134     0.707071     0.538043     0.639785
# 123438      0.243590     0.731959     0.525253     0.717029     0.759140
# 82855       0.141026     0.628866     0.484848     0.528986     0.591398
#
#         Cloud9am  Cloud3pm   Temp9am   Temp3pm  RainToday
# 141820     0.750     0.125  0.382831  0.472727        0.0
# 14561      0.475     0.650  0.730858  0.763636        0.0
# 77240      0.875     0.875  0.580046  0.410101        0.0
# 123438     0.675     0.600  0.422274  0.464646        0.0
# 82855      0.000     0.125  0.672854  0.618182        1.0

# %%
from datetime import datetime
print(datetime.now())
# Out:
# 2021-10-06 10:48:58.635072

# %%
miss_train = (X_train.isnull().sum()).sort_values(ascending=False)
miss_train.isnull().any()
# Out:
# False

# %%
miss_test = (X_train.isnull().sum()).sort_values(ascending=False)
miss_test.isnull().any()
# Out:
# False

# %%
weather_data['RainTomorrow'].value_counts(normalize=True)
# Out:
# 0    0.775441
# 1    0.224559
# Name: RainTomorrow, dtype: float64

# %%
y.value_counts(normalize=True)
# Out:
# 0    0.775441
# 1    0.224559
# Name: RainTomorrow, dtype: float64

# %% [markdown]
# ### Check if any columns has VIF. Note: Correlation is NOT affected by scaling.

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

vif_values = pd.DataFrame(
                {'feature' : X_train.columns,
                 'vif' : [variance_inflation_factor(X_train.values, i) for i  in range(X_train.shape[1])]                   
                }).sort_values(by='vif', ascending=False)
vif_values
# Out:
#           feature         vif
# 15    Pressure3pm  515.371135
# 14    Pressure9am  471.217614
# 2         MaxTemp  365.017329
# 19        Temp3pm  339.854770
# 18        Temp9am  254.983286
# 1         MinTemp   87.224761
# 12    Humidity9am   44.456561
# 13    Humidity3pm   33.305926
# 7   WindGustSpeed   15.227177
# 5        Sunshine   12.189829
# 11   WindSpeed3pm   10.148278
# 17       Cloud3pm    8.864989
# 16       Cloud9am    7.697534
# 10   WindSpeed9am    6.456300
# 9      WindDir3pm    5.879422
# 6     WindGustDir    5.572989
# 4     Evaporation    4.906786
# 8      WindDir9am    4.408647
# 0        Location    3.814410
# 20      RainToday    2.168397
# 3        Rainfall    1.517006

# %%
import seaborn as sns
corr=X_train.iloc[:,:-1].corr()
top_features=corr.index
plt.figure(figsize=(20,20))
sns.heatmap(X_train[top_features].corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
corr
# Out:
#                Location   MinTemp   MaxTemp  Rainfall  Evaporation  Sunshine  \
# Location       1.000000 -0.020466 -0.039481 -0.016493     0.020469 -0.050257
# MinTemp       -0.020466  1.000000  0.733479  0.113805     0.347247  0.055590
# MaxTemp       -0.039481  0.733479  1.000000 -0.074878     0.457975  0.337143
# Rainfall      -0.016493  0.113805 -0.074878  1.000000    -0.060978 -0.170400
# Evaporation    0.020469  0.347247  0.457975 -0.060978     1.000000  0.307094
# Sunshine      -0.050257  0.055590  0.337143 -0.170400     0.307094  1.000000
# WindGustDir   -0.012917 -0.113224 -0.207866  0.039819    -0.090434 -0.106203
# WindGustSpeed  0.079731  0.170717  0.079980  0.121426     0.149613 -0.009663
# WindDir9am    -0.003974 -0.107100 -0.240232  0.065260    -0.140442 -0.127867
# WindDir3pm     0.009128 -0.136438 -0.178189  0.044878    -0.035168 -0.059575
# WindSpeed9am   0.083454  0.172836  0.019814  0.069472     0.134382  0.024344
# WindSpeed3pm   0.070043  0.162684  0.048921  0.037208     0.089122  0.043927
# Humidity9am   -0.003633 -0.227535 -0.499586  0.223544    -0.403898 -0.353829
# Humidity3pm    0.011388  0.006170 -0.499465  0.264576    -0.317797 -0.452762
# Pressure9am    0.049987 -0.415925 -0.295306 -0.154060    -0.204656  0.044211
# Pressure3pm    0.067711 -0.428866 -0.390981 -0.112920    -0.230215 -0.010161
# Cloud9am      -0.009942  0.029608 -0.253092  0.163642    -0.154229 -0.538121
# Cloud3pm      -0.025066 -0.019254 -0.242253  0.149590    -0.159475 -0.565272
# Temp9am       -0.032535  0.899192  0.886846  0.016784     0.423711  0.210797
# Temp3pm       -0.037384  0.695610  0.971092 -0.083298     0.445250  0.359055
#
#                WindGustDir  WindGustSpeed  WindDir9am  WindDir3pm  \
# Location         -0.012917       0.079731   -0.003974    0.009128
# MinTemp          -0.113224       0.170717   -0.107100   -0.136438
# MaxTemp          -0.207866       0.079980   -0.240232   -0.178189
# Rainfall          0.039819       0.121426    0.065260    0.044878
# Evaporation      -0.090434       0.149613   -0.140442   -0.035168
# Sunshine         -0.106203      -0.009663   -0.127867   -0.059575
# WindGustDir       1.000000       0.124757    0.362460    0.549889
# WindGustSpeed     0.124757       1.000000   -0.032778    0.144170
# WindDir9am        0.362460      -0.032778    1.000000    0.295730
# WindDir3pm        0.549889       0.144170    0.295730    1.000000
# WindSpeed9am     -0.014280       0.561829   -0.162047    0.037717
# WindSpeed3pm      0.051375       0.629300   -0.021290    0.039881
# Humidity9am       0.079469      -0.221264    0.202690    0.042003
# Humidity3pm       0.090267      -0.044495    0.177619    0.027854
# Pressure9am      -0.120788      -0.428007    0.027426   -0.145439
# Pressure3pm      -0.022637      -0.382744    0.111862   -0.039001
# Cloud9am          0.085796       0.035580    0.101550    0.075210
# Cloud3pm          0.088442       0.076430    0.059803    0.084753
# Temp9am          -0.165737       0.150388   -0.189294   -0.164888
# Temp3pm          -0.220065       0.045004   -0.241825   -0.190640
#
#                WindSpeed9am  WindSpeed3pm  Humidity9am  Humidity3pm  \
# Location           0.083454      0.070043    -0.003633     0.011388
# MinTemp            0.172836      0.162684    -0.227535     0.006170
# MaxTemp            0.019814      0.048921    -0.499586    -0.499465
# Rainfall           0.069472      0.037208     0.223544     0.264576
# Evaporation        0.134382      0.089122    -0.403898    -0.317797
# Sunshine           0.024344      0.043927    -0.353829    -0.452762
# WindGustDir       -0.014280      0.051375     0.079469     0.090267
# WindGustSpeed      0.561829      0.629300    -0.221264    -0.044495
# WindDir9am        -0.162047     -0.021290     0.202690     0.177619
# WindDir3pm         0.037717      0.039881     0.042003     0.027854
# WindSpeed9am       1.000000      0.510032    -0.288511    -0.047649
# WindSpeed3pm       0.510032      1.000000    -0.154785    -0.002697
# Humidity9am       -0.288511     -0.154785     1.000000     0.669083
# Humidity3pm       -0.047649     -0.002697     0.669083     1.000000
# Pressure9am       -0.226128     -0.267449     0.132604    -0.025376
# Pressure3pm       -0.175525     -0.233485     0.180363     0.056342
# Cloud9am          -0.006891      0.033027     0.356142     0.405924
# Cloud3pm           0.026769      0.016212     0.283880     0.407643
# Temp9am            0.127705      0.154345    -0.465185    -0.223959
# Temp3pm            0.007146      0.032429    -0.495660    -0.559440
#
#                Pressure9am  Pressure3pm  Cloud9am  Cloud3pm   Temp9am  \
# Location          0.049987     0.067711 -0.009942 -0.025066 -0.032535
# MinTemp          -0.415925    -0.428866  0.029608 -0.019254  0.899192
# MaxTemp          -0.295306    -0.390981 -0.253092 -0.242253  0.886846
# Rainfall         -0.154060    -0.112920  0.163642  0.149590  0.016784
# Evaporation      -0.204656    -0.230215 -0.154229 -0.159475  0.423711
# Sunshine          0.044211    -0.010161 -0.538121 -0.565272  0.210797
# WindGustDir      -0.120788    -0.022637  0.085796  0.088442 -0.165737
# WindGustSpeed    -0.428007    -0.382744  0.035580  0.076430  0.150388
# WindDir9am        0.027426     0.111862  0.101550  0.059803 -0.189294
# WindDir3pm       -0.145439    -0.039001  0.075210  0.084753 -0.164888
# WindSpeed9am     -0.226128    -0.175525 -0.006891  0.026769  0.127705
# WindSpeed3pm     -0.267449    -0.233485  0.033027  0.016212  0.154345
# Humidity9am       0.132604     0.180363  0.356142  0.283880 -0.465185
# Humidity3pm      -0.025376     0.056342  0.405924  0.407643 -0.223959
# Pressure9am       1.000000     0.958794 -0.101463 -0.126276 -0.385064
# Pressure3pm       0.958794     1.000000 -0.039207 -0.071134 -0.434710
# Cloud9am         -0.101463    -0.039207  1.000000  0.576849 -0.135659
# Cloud3pm         -0.126276    -0.071134  0.576849  1.000000 -0.132128
# Temp9am          -0.385064    -0.434710 -0.135659 -0.132128  1.000000
# Temp3pm          -0.251619    -0.354155 -0.261900 -0.278446  0.850328
#
#                 Temp3pm
# Location      -0.037384
# MinTemp        0.695610
# MaxTemp        0.971092
# Rainfall      -0.083298
# Evaporation    0.445250
# Sunshine       0.359055
# WindGustDir   -0.220065
# WindGustSpeed  0.045004
# WindDir9am    -0.241825
# WindDir3pm    -0.190640
# WindSpeed9am   0.007146
# WindSpeed3pm   0.032429
# Humidity9am   -0.495660
# Humidity3pm   -0.559440
# Pressure9am   -0.251619
# Pressure3pm   -0.354155
# Cloud9am      -0.261900
# Cloud3pm      -0.278446
# Temp9am        0.850328
# Temp3pm        1.000000

# %%
for row in corr.index:
    for col in corr.columns:
        if abs(corr.loc[row, col]) > 0.7 and row != col:
            print(row, col, round(corr.loc[row, col], 4))
# Out:
# MinTemp MaxTemp 0.7335
# MinTemp Temp9am 0.8992
# MaxTemp MinTemp 0.7335
# MaxTemp Temp9am 0.8868
# MaxTemp Temp3pm 0.9711
# Pressure9am Pressure3pm 0.9588
# Pressure3pm Pressure9am 0.9588
# Temp9am MinTemp 0.8992
# Temp9am MaxTemp 0.8868
# Temp9am Temp3pm 0.8503
# Temp3pm MaxTemp 0.9711
# Temp3pm Temp9am 0.8503

# %% [markdown]
# ### We see a lot of correlated values here, lets select top 10 features and see if this correlation would go off!

# %%
from sklearn.ensemble import ExtraTreesClassifier
model = ExtraTreesClassifier()
model.fit(X_train, y_train)

print(model.feature_importances_)
print(X_train.columns)

ranked_features=pd.Series(model.feature_importances_,index=X_train.columns)
ranked_features.nlargest(10).plot(kind='barh')
plt.show()
# Out:
# [0.03519072 0.03766399 0.03730758 0.03823306 0.03447395 0.06191648
#  0.0345602  0.05211057 0.03429367 0.03509409 0.03650837 0.03644867
#  0.0509473  0.14518078 0.04385059 0.04980469 0.04349183 0.05333286
#  0.03666021 0.04108984 0.06184054]
# Index(['Location', 'MinTemp', 'MaxTemp', 'Rainfall', 'Evaporation', 'Sunshine',
#        'WindGustDir', 'WindGustSpeed', 'WindDir9am', 'WindDir3pm',
#        'WindSpeed9am', 'WindSpeed3pm', 'Humidity9am', 'Humidity3pm',
#        'Pressure9am', 'Pressure3pm', 'Cloud9am', 'Cloud3pm', 'Temp9am',
#        'Temp3pm', 'RainToday'],
#       dtype='object')

# %%
# Lets check with another method - SelectKBest

from sklearn.feature_selection import SelectKBest, chi2

ordered_rank_features=SelectKBest(score_func=chi2, k=10)
ordered_feature=ordered_rank_features.fit(X_train,y_train)

dfscores=pd.DataFrame(ordered_feature.scores_)
dfcolumns=pd.DataFrame(X.columns)
features_rank = pd.DataFrame({
                        'features' : X_train.columns,
                        'score' : ordered_feature.scores_}).sort_values(by='score', ascending=False)


features_rank
# Out:
#          features       score
# 20      RainToday  794.649525
# 13    Humidity3pm  176.987296
# 17       Cloud3pm  118.092554
# 6     WindGustDir  107.528678
# 16       Cloud9am  106.006035
# 3        Rainfall   96.720735
# 5        Sunshine   93.483807
# 9      WindDir3pm   70.428469
# 12    Humidity9am   39.805091
# 8      WindDir9am   28.450690
# 7   WindGustSpeed   18.457137
# 0        Location   17.997769
# 19        Temp3pm   16.377432
# 14    Pressure9am   12.448847
# 2         MaxTemp   12.045808
# 15    Pressure3pm    9.124440
# 10   WindSpeed9am    7.439669
# 4     Evaporation    4.640990
# 11   WindSpeed3pm    2.654380
# 1         MinTemp    2.532717
# 18        Temp9am    0.883349

# %%
list1 = ranked_features.nlargest(10).index[:10]
list1
# Out:
# Index(['Humidity3pm', 'Sunshine', 'RainToday', 'Cloud3pm', 'WindGustSpeed',
#        'Humidity9am', 'Pressure3pm', 'Pressure9am', 'Cloud9am', 'Temp3pm'],
#       dtype='object')

# %%
list2 = features_rank['features'].values[:10]
list2
# Out:
# array(['RainToday', 'Humidity3pm', 'Cloud3pm', 'WindGustDir', 'Cloud9am',
#        'Rainfall', 'Sunshine', 'WindDir3pm', 'Humidity9am', 'WindDir9am'],
#       dtype=object)

# %%
common_features = [i for i in list1 if i in list2]
print(common_features)
# Out:
# ['Humidity3pm', 'Sunshine', 'RainToday', 'Cloud3pm', 'Humidity9am', 'Cloud9am']

# %% [markdown]
# #### However, lets take list2 as it has a Categorical Feature - WindGustDir

# %%
categorical_columns
# Out:
# Index(['Location', 'WindGustDir', 'WindDir9am', 'WindDir3pm'], dtype='object')

# %%
final_features = list2[:6]
final_features
# Out:
# array(['RainToday', 'Humidity3pm', 'Cloud3pm', 'WindGustDir', 'Cloud9am',
#        'Rainfall'], dtype=object)

# %% [markdown]
# ### Looks like these features are fine as there is no correlation also &#x1F60E; &#128517;

# %%
X_train = X_train[final_features]
X_test = X_test[final_features]

# %%
X_train.shape, X_test.shape
# Out:
# ((9953, 6), (4266, 6))

# %%
weather_train = pd.concat([X_train, y_train], axis=1)
weather_train.to_csv('weather_train.csv', index=False)

weather_test = pd.concat([X_test, y_test], axis=1)
weather_test.to_csv('weather_test.csv', index=False)

# %%
X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((9953, 6), (9953,), (4266, 6), (4266,))

# %%
X_train.head()
# Out:
#         RainToday  Humidity3pm  Cloud3pm  WindGustDir  Cloud9am  Rainfall
# 12602         0.0     0.414141     1.000          0.0     0.250  0.001142
# 106853        1.0     0.575758     0.375         17.0     0.750  0.036530
# 11728         0.0     0.777778     0.500         12.0     1.000  0.000000
# 55878         0.0     0.525253     1.000         14.0     0.875  0.000000
# 12495         0.0     0.333333     0.000          0.0     0.750  0.000000

# %%
X_test.head()
# Out:
#         RainToday  Humidity3pm  Cloud3pm  WindGustDir  Cloud9am  Rainfall
# 141820        0.0     0.343434     0.125         17.0     0.750  0.000000
# 14561         0.0     0.191919     0.650          4.0     0.475  0.000000
# 77240         0.0     0.707071     0.875          3.0     0.875  0.000000
# 123438        0.0     0.525253     0.600         15.0     0.675  0.000000
# 82855         1.0     0.484848     0.125          1.0     0.000  0.035388

# %% [markdown]
# ## Now lets go for the model creation step, finally &#x1F60C;
#
# **Lets save the data into .csv so that we can use in another notebook for model building**

# %%
from sklearn.tree import DecisionTreeClassifier

dt = DecisionTreeClassifier()
dt.fit(X_train, y_train)
dt.score(X_test, y_test)
# Out:
# 0.7423816221284576

# %%
from sklearn.metrics import classification_report

y_pred = dt.predict(X_test)

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.83      0.83      3312
#            1       0.43      0.44      0.43       954
#
#     accuracy                           0.74      4266
#    macro avg       0.63      0.64      0.63      4266
# weighted avg       0.75      0.74      0.74      4266

# %% [markdown]
# * Full data result: 0.84 and 0.50 recall for 0 and 1
# * 10pct data - 0.82 and 0.48 recall for 0 and 1
# * removing 4 columns with nan values gt 35 - on 10pct data 0.84 and 0.46 recall for 0 and 1
# * with 6 features on 10pct data 0.84 and 0.46 for recall 0 and 1
